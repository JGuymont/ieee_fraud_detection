# %%
import pandas
import numpy
import sys
import time

sys.path.append('..')

# %%
train_transaction_csv_path = '../data/raw/train_transaction.csv'
train_transaction_hdf_path = '../data/interim/train_transaction.h5'

# %%
t0 = time.time()
df = pandas.read_csv('../data/raw/train_transaction.csv')
round(time.time() - t0)
# Out:
# 22

# %%
t0 = time.time()
test = pandas.read_hdf(train_transaction_hdf_path, start=0, stop=2)
round(time.time() - t0)

test
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt  ProductCD  card1  \
# 0        2987000        0          86400            68.5          4  10095
# 1        2987001        0          86401            29.0          4   1372
#
#    card2  card3  card4  card5  ...  V330  V331  V332  V333  V334  V335  V336  \
# 0     -1     42      1     38  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    303     42      2      2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    V337  V338  V339
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
#
# [2 rows x 394 columns]

# %%
categorical_features = ['ProductCD', 'addr1', 'addr2', 'P_emaildomain', 'R_emaildomain']
categorical_features += ['card{}'.format(i) for i in range(1, 7)]
categorical_features += ['M{}'.format(i) for i in range(1, 10)]
categorical_features += ['isFraud']

numerical_features = [feature for feature in list(df) if feature not in categorical_features]
integer_features = [feature for feature in numerical_features if df[feature].dtype == numpy.int64]
continuous_features = [feature for feature in numerical_features if df[feature].dtype == numpy.float64]

# %%
df[integer_features]
# Out:
#     TransactionID  TransactionDT
# 0         2987000          86400
# 1         2987001          86401
# 2         2987002          86469
# 3         2987003          86499
# 4         2987004          86506
# ..            ...            ...
# 95        2987095          88120
# 96        2987096          88131
# 97        2987097          88147
# 98        2987098          88149
# 99        2987099          88162
#
# [100 rows x 2 columns]

# %%
set(df.dtypes)
# Out:
# {CategoricalDtype(categories=['credit', 'debit'], ordered=False),
#  CategoricalDtype(categories=[122.0, 126.0, 170.0, 181.0, 184.0, 191.0, 204.0, 205.0,
#                    220.0, 226.0, 231.0, 251.0, 264.0, 272.0, 299.0, 315.0,
#                    325.0, 330.0, 337.0, 387.0, 420.0, 436.0, 441.0, 469.0,
#                    472.0, 476.0, 485.0],
#                   ordered=False),
#  CategoricalDtype(categories=[0], ordered=False),
#  CategoricalDtype(categories=[117.0, 150.0, 185.0], ordered=False),
#  CategoricalDtype(categories=[87.0], ordered=False),
#  CategoricalDtype(categories=['anonymous.com', 'charter.net', 'gmail.com', 'hotmail.com',
#                    'outlook.com'],
#                   ordered=False),
#  CategoricalDtype(categories=[100.0, 103.0, 111.0, 114.0, 143.0, 148.0, 170.0, 174.0,
#                    199.0, 206.0, 243.0, 264.0, 266.0, 269.0, 272.0, 285.0,
#                    302.0, 303.0, 314.0, 321.0, 343.0, 352.0, 360.0, 361.0,
# ...

# %%
for feature in categorical_features:
    df[feature] = df[feature].astype('category').cat.codes

# %%
for feature in integer_features:
    if df[feature].dtype == numpy.int64:
        df[feature] = df[feature].astype('int32')

# %%
for feature in continuous_features:
    if df[feature].dtype == numpy.float64:
        df[feature] = df[feature].astype('float32')

# %%
df
# Out:
#     TransactionID  isFraud  TransactionDT  TransactionAmt  ProductCD  card1  \
# 0         2987000        0          86400            68.5          4     63
# 1         2987001        0          86401            29.0          4     11
# 2         2987002        0          86469            59.0          4     21
# 3         2987003        0          86499            50.0          4     83
# 4         2987004        0          86506            50.0          1     19
# ..            ...      ...            ...             ...        ...    ...
# 95        2987095        0          88120            59.0          4      9
# 96        2987096        0          88131           108.5          4     69
# 97        2987097        0          88147            21.5          4     10
# 98        2987098        0          88149           159.0          4     28
# 99        2987099        0          88162            75.0          2      0
#
# ...

# %%
df[categorical_features] = df[categorical_features].apply(lambda x: x.cat.codes)

# %%
df[categorical_features]
df.to_hdf('test.h5' ,'table')
